# %%
import subprocess
from Bio import Entrez
from Bio import SeqIO
from Bio import SearchIO
Entrez.email = "o.william.white@gmail.com"

# %%
# input parameters
reference_accession = "NC_000932.1"
query_accession = "NC_000932.1"

# %%
## download genbank of reference data and write annotated genes to fasta

# efetch accession
handle = Entrez.efetch(db="nucleotide", id=reference_accession, rettype="gb", retmode="text")
record = SeqIO.read(handle, "gb")
handle.close()

# set up empty list
gene_list = []
gene_count = {}

# loop through sequence feature and append to list
for feature in record.features:
    # cds features
    if feature.type == "CDS" and "gene" in feature.qualifiers.keys():
        
        gene_name = feature.qualifiers["gene"][0]

        # blat requires reference data with uniq names
        if gene_count.get(gene_name) is None:
            gene_count[gene_name] = 1
        else: 
            gene_count[gene_name] += 1
            gene_name = gene_name + "_" + str(gene_count[gene_name])
        
        gene_seq = feature.extract(record)
        gene_seq.id = gene_name
        gene_seq.description = ""
        gene_list.append(gene_seq)

# write reference fasta
with open("reference.fasta", "w") as ref:
    SeqIO.write(gene_list, ref, "fasta")

# %%
## download query accession and write to fasta

# efetch accession
handle = Entrez.efetch(db="nucleotide", id=query_accession, rettype="fasta", retmode="text")
record = SeqIO.read(handle, "fasta")
handle.close()

# write reference fasta
with open("query.fasta", "w") as que:
    SeqIO.write(record, que, "fasta")

# %%
# run blat
subprocess.run(["blat", "reference.fasta",  "query.fasta", "output.psl"])
# Out:
# Loaded 79482 letters in 85 sequences
# Searched 154478 bases in 1 sequences
# CompletedProcess(args=['blat', 'reference.fasta', 'query.fasta', 'output.psl'], returncode=0)

# %%
blat_output = SearchIO.read("output.psl", "blat-psl")

# %%
print(blat_output)
# Out:
# Program: blat (<unknown version>)
#   Query: NC_000932.1 (154478)
#          <unknown description>
#  Target: <unknown target>
#    Hits: ----  -----  ----------------------------------------------------------
#             #  # HSP  ID + description
#          ----  -----  ----------------------------------------------------------
#             0      2  rps19  <unknown description>
#             1      2  rpl2_2  <unknown description>
#             2      2  rpl23_2  <unknown description>
#             3      2  rpl23  <unknown description>
#             4      2  rpl2  <unknown description>
#             5      2  rps7_2  <unknown description>
#             6      2  rps7  <unknown description>
#             7      3  rps12_2  <unknown description>
#             8      3  rps12  <unknown description>
#             9      2  ndhF  <unknown description>
#            10      1  rpl32  <unknown description>
#            11      1  ccsA  <unknown description>
#            12      2  ycf1  <unknown description>
#            13      2  ndhB_2  <unknown description>
#            14      2  ndhB  <unknown description>
#            15      2  ycf2_2  <unknown description>
#            16      2  ycf2  <unknown description>
#            17      1  petD  <unknown description>
#            18      1  psbT  <unknown description>
#            19      1  psbH  <unknown description>
#            20      1  petB  <unknown description>
#            21      1  psbB  <unknown description>
#            22      1  rps18  <unknown description>
#            23      1  rpl33  <unknown description>
#            24      1  psaJ  <unknown description>
#            25      1  petL  <unknown description>
#            26      1  petG  <unknown description>
#            27      1  ycf4  <unknown description>
#            28      1  petA  <unknown description>
#            29      1  cemA  <unknown description>
#            ~~~
#            82      1  rps15  <unknown description>
#            83      1  ndhH  <unknown description>
#            84      1  ndhA  <unknown description>

# %%
for hit in blat_output:
    print(hit)
# Out:
# Query: NC_000932.1
#        <unknown description>
#   Hit: rps19 (279)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [154365:154478]                [0:113]
#           1         ?          ?       ?    [84004:84283]                [0:279]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rpl2_2 (825)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [152805:154312]                [0:825]
#           1         ?          ?       ?    [84336:85843]                [0:825]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rpl23_2 (282)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [152505:152787]                [0:282]
#           1         ?          ?       ?    [85861:86143]                [0:282]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rpl23 (282)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [152505:152787]                [0:282]
#           1         ?          ?       ?    [85861:86143]                [0:282]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rpl2 (825)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [152805:154312]                [0:825]
#           1         ?          ?       ?    [84336:85843]                [0:825]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rps7_2 (468)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [140703:141171]                [0:468]
#           1         ?          ?       ?    [97477:97945]                [0:468]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rps7 (468)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [140703:141171]                [0:468]
#           1         ?          ?       ?    [97477:97945]                [0:468]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rps12_2 (372)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [139855:140087]              [114:346]
#           1         ?          ?       ?    [98561:98793]              [114:346]
#           2         ?          ?       ?    [69610:69724]                [0:114]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rps12 (372)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [139855:140087]              [114:346]
#           1         ?          ?       ?    [98561:98793]              [114:346]
#           2         ?          ?       ?    [69610:69724]                [0:114]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ndhF (2241)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [128214:128251]            [2204:2241]
#           1         ?          ?       ?  [110397:112638]               [0:2241]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rpl32 (159)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [113448:113607]                [0:159]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ccsA (987)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [114460:115447]                [0:987]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ycf1 (1032)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [109404:110436]               [0:1032]
#           1         ?          ?       ?  [128214:129244]               [0:1030]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ndhB_2 (1539)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [141484:143708]               [0:1539]
#           1         ?          ?       ?    [94940:97164]               [0:1539]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ndhB (1539)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [141484:143708]               [0:1539]
#           1         ?          ?       ?    [94940:97164]               [0:1539]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ycf2_2 (6885)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [86473:93358]               [0:6885]
#           1         ?          ?       ?  [145290:152175]               [0:6885]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ycf2 (6885)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [86473:93358]               [0:6885]
#           1         ?          ?       ?  [145290:152175]               [0:6885]
# Query: NC_000932.1
#        <unknown description>
#   Hit: petD (483)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [77196:77672]                [7:483]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psbT (102)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [74081:74183]                [0:102]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psbH (222)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [74484:74706]                [0:222]
# Query: NC_000932.1
#        <unknown description>
#   Hit: petB (648)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [75649:76292]                [5:648]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psbB (1527)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [72370:73897]               [0:1527]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rps18 (306)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [67916:68222]                [0:306]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rpl33 (201)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [67487:67688]                [0:201]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psaJ (135)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [66928:67063]                [0:135]
# Query: NC_000932.1
#        <unknown description>
#   Hit: petL (96)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [65711:65807]                 [0:96]
# Query: NC_000932.1
#        <unknown description>
#   Hit: petG (114)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [65997:66111]                [0:114]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ycf4 (555)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [59771:60326]                [0:555]
# Query: NC_000932.1
#        <unknown description>
#   Hit: petA (963)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [61656:62619]                [0:963]
# Query: NC_000932.1
#        <unknown description>
#   Hit: cemA (690)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [60740:61430]                [0:690]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psaI (114)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [59246:59360]                [0:114]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rbcL (1440)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [54957:56397]               [0:1440]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psbZ (189)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [35750:35939]                [0:189]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psbD (1062)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [32710:33772]               [0:1062]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psbC (1422)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [33719:35141]               [0:1422]
# Query: NC_000932.1
#        <unknown description>
#   Hit: petN (90)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [28088:28178]                 [0:90]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psbK (186)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?      [7016:7202]                [0:186]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psbI (111)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?      [7582:7693]                [0:111]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ycf1_2 (5361)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [109404:110434]               [0:1030]
#           1         ?          ?       ?  [123883:129244]               [0:5361]
# Query: NC_000932.1
#        <unknown description>
#   Hit: accD (1467)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [57074:58541]               [0:1467]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psbA (1062)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?       [382:1444]               [0:1062]
# Query: NC_000932.1
#        <unknown description>
#   Hit: matK (1515)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?      [2055:3570]               [0:1515]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rps16 (240)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?      [5083:6188]                [0:240]
# Query: NC_000932.1
#        <unknown description>
#   Hit: atpH (246)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [13261:13507]                [0:246]
# Query: NC_000932.1
#        <unknown description>
#   Hit: atpF (555)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [11528:12798]                [0:555]
# Query: NC_000932.1
#        <unknown description>
#   Hit: atpA (1524)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?     [9937:11461]               [0:1524]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rps2 (711)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [15012:15723]                [0:711]
# Query: NC_000932.1
#        <unknown description>
#   Hit: atpI (750)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [14020:14770]                [0:750]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rpoC2 (4131)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [15937:20068]               [0:4131]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rpoC1 (2043)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [20250:23084]               [0:2043]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rpoB (3219)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [23110:26329]               [0:3219]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psbM (105)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [28706:28811]                [0:105]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rps14 (303)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [36937:37240]                [0:303]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psaB (2205)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [37374:39579]               [0:2205]
#           1         ?          ?       ?    [40928:41001]              [802:875]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psaA (2253)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [39604:41857]               [0:2253]
#           1         ?          ?       ?    [38704:38777]              [856:929]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ycf3 (507)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [42583:44591]                [0:507]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rps4 (606)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [45222:45828]                [0:606]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ndhK (678)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [49256:49934]                [0:678]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ndhJ (477)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [48676:49153]                [0:477]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ndhC (363)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [50000:50363]                [0:363]
# Query: NC_000932.1
#        <unknown description>
#   Hit: atpE (399)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [52264:52663]                [0:399]
# Query: NC_000932.1
#        <unknown description>
#   Hit: atpB (1497)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [52659:54156]               [0:1497]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psbL (117)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [63803:63920]                [0:117]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psbJ (123)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [63537:63660]                [0:123]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psbF (120)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [63941:64061]                [0:120]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psbE (252)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [64070:64322]                [0:252]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rpl20 (354)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [68511:68865]                [0:354]
# Query: NC_000932.1
#        <unknown description>
#   Hit: clpP (591)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [69909:71882]                [0:591]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psbN (132)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [74248:74380]                [0:132]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rps8 (405)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [80067:80472]                [0:405]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rps11 (417)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [78959:79376]                [0:417]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rpoA (990)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [77900:78890]                [0:990]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rpl36 (114)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [79488:79602]                [0:114]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rpl16 (408)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [81188:81587]                [9:408]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rpl14 (369)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [80695:81064]                [0:369]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rps3 (657)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [82825:83482]                [0:657]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rpl22 (483)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?    [83466:83949]                [0:483]
# Query: NC_000932.1
#        <unknown description>
#   Hit: psaC (246)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [117317:117563]                [0:246]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ndhI (519)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [119243:119762]                [0:519]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ndhG (531)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [118376:118907]                [0:531]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ndhE (306)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [117803:118109]                [0:306]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ndhD (1503)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [115664:117167]               [0:1503]
# Query: NC_000932.1
#        <unknown description>
#   Hit: rps15 (267)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [123295:123562]                [0:267]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ndhH (1182)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [122010:123192]               [0:1182]
# Query: NC_000932.1
#        <unknown description>
#   Hit: ndhA (1083)
#        <unknown description>
#  HSPs: ----  --------  ---------  ------  ---------------  ---------------------
#           #   E-value  Bit score    Span      Query range              Hit range
#        ----  --------  ---------  ------  ---------------  ---------------------
#           0         ?          ?       ?  [119846:122009]               [0:1083]
